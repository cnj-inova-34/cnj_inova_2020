# %% [markdown]
# ## Problema
# Os dados disponibilizados apresentam informações irrelevantes para a solução proposta.
# Também possuem dados qualidade inadequada e que precisam ser corrigidos.
#
# ## Solução
# Criar visão da tabela de "processos / movimentos" com remoção dos campos que já sabemos não serem relevantes para a solução proposta.
# Será feita uma primeira melhoria na qualidade dos dados.
# Por fim, incluir informações das tabelas auxiliares facilitará etapas posteriores.

# %%
import pandas as pd
import numpy as np
import os
import fnmatch
import pandas_assistente as pa

origem_dados = 'dados/01_tabelas_extraidas/'
destino_dados = 'dados/02_tabelas_transformadas/'

# campos não relevantes
nao_relevantes = ['dadosBasicos_assunto_assuntoLocal_codigoAssunto', 'dadosBasicos_competencia',
                  'dadosBasicos_nivelSigilo', 'dadosBasicos_valorCausa', 'movimento_movimentoLocal_codigoMovimento', 'movimento']

# %%
# Carregar tabelas auxiliares
def carregar_tabelas_auxiliares():

    data_path = 'dados/01_tabelas_auxiliares/'

    # carrega dados
    tabAssunto = pd.read_csv(data_path + 'tabAssunto.csv', usecols=['cod_assunto','descricao_assunto', 'descricao_assunto_pai'])
    tabClasse = pd.read_csv(data_path + 'tabClasse.csv', usecols=['cod_classe','descricao_classe', 'descricao_classe_pai'])
    tabMovimento = pd.read_csv(data_path + 'tabMovimento.csv', usecols=['cod_movimento','descricao_movimento', 'descricao_movimento_pai'])

    return tabAssunto, tabClasse, tabMovimento

# %%
# Ajusta datas
def ajustar_datas(tabela):
    
    # dataInsercao
    tabela = pa.converter_campo_data(tabela, 'millisInsercao', 'data_insercao')
    
    # dataAjuizamento
    tabela = pa.converter_campo_data(tabela, 'dadosBasicos_dataAjuizamento', 'data_ajuizamento')
    
    # movimento_dataHora
    tabela = pa.converter_campo_data(tabela, 'movimento_dataHora', 'data_movimento')
        
    return tabela

# %%
# Transformar processo
def transformar_processo(diretorio, arquivo_id):

    # Carga dos processos
    print(origem_dados + diretorio + arquivo_id)
    processos = pa.carregar_tabela(origem_dados + diretorio + arquivo_id, nao_relevantes)
    
    # Diversos ajustes
    ajustar_datas(processos)

    # Campos auxiliares
    processos = pa.merge_tabelas(processos, tabClasse, 'cod_classe', 'dadosBasicos_classeProcessual')
    processos = pa.merge_tabelas(processos, tabAssunto, 'cod_assunto', 'dadosBasicos_assunto_codigoNacional',
                                 'dadosBasicos_assunto_assuntoLocal_codigoPaiNacional')
    processos = pa.merge_tabelas(processos, tabMovimento, 'cod_movimento', 'movimento_movimentoNacional_codigoNacional', 
                                 'movimento_movimentoLocal_codigoPaiNacional')

    # Salvar arquivo .CSV
    processos.to_csv(destino_dados + diretorio + arquivo_id, index=False)
    print(processos.shape)

# %%
# Faz o loop em todos os arquivos do diretório e efetua transformação dos processos
def transformar_processos(diretorio):

    print('Tranformação inciada: ' + origem_dados + diretorio)
    for file in fnmatch.filter(os.listdir(origem_dados + diretorio), 'processos-*.csv'):
        file_name = file.split('.')
        print('Transformando tabela: ' + file)
        transformar_processo(diretorio, file)
        print()

# %%
# Execução do código 

tabAssunto, tabClasse, tabMovimento = carregar_tabelas_auxiliares()

transformar_processos('00_justica_federal/processos-trf1/')
transformar_processos('00_justica_federal/processos-trf2/')
transformar_processos('00_justica_federal/processos-trf3/')
transformar_processos('00_justica_federal/processos-trf4/')
transformar_processos('00_justica_federal/processos-trf5/')
print("Finalizada transformação das tabelas!!")
# Out:
# Ajustando tabela: processos-trf1_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_1.csv
# (56651, 24)
#
# Ajustando tabela: processos-trf1_10.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_10.csv
# (5959, 24)
#
# Ajustando tabela: processos-trf1_11.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_11.csv
# (928, 24)
#
# Ajustando tabela: processos-trf1_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_2.csv
# (496649, 24)
#
# Ajustando tabela: processos-trf1_3.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_3.csv
# (379776, 24)
#
# Ajustando tabela: processos-trf1_4.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_4.csv
# (83254, 24)
#
# Ajustando tabela: processos-trf1_5.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_5.csv
# (755999, 24)
#
# Ajustando tabela: processos-trf1_6.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_6.csv
# (627224, 24)
#
# Ajustando tabela: processos-trf1_7.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_7.csv
# (524595, 24)
#
# Ajustando tabela: processos-trf1_8.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_8.csv
# (82038, 24)
#
# Ajustando tabela: processos-trf1_9.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf1/processos-trf1_9.csv
# (5399, 24)
#
# Ajustando tabela: processos-trf2_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_1.csv
# (22641, 25)
#
# Ajustando tabela: processos-trf2_10.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_10.csv
# (6158, 25)
#
# Ajustando tabela: processos-trf2_11.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_11.csv
# (1872, 25)
#
# Ajustando tabela: processos-trf2_12.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_12.csv
# (89, 25)
#
# Ajustando tabela: processos-trf2_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_2.csv
# (21162, 25)
#
# Ajustando tabela: processos-trf2_3.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_3.csv
# (8917, 25)
#
# Ajustando tabela: processos-trf2_4.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_4.csv
# (766, 25)
#
# Ajustando tabela: processos-trf2_5.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_5.csv
# (19071, 25)
#
# Ajustando tabela: processos-trf2_6.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_6.csv
# (16090, 25)
#
# Ajustando tabela: processos-trf2_7.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_7.csv
# (9616, 25)
#
# Ajustando tabela: processos-trf2_8.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_8.csv
# (1074, 25)
#
# Ajustando tabela: processos-trf2_9.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf2/processos-trf2_9.csv
# (10960, 25)
#
# Ajustando tabela: processos-trf3_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_1.csv
# (141589, 25)
#
# Ajustando tabela: processos-trf3_10.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_10.csv
# (58190, 30)
#
# Ajustando tabela: processos-trf3_11.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_11.csv
# (30629, 30)
#
# Ajustando tabela: processos-trf3_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_2.csv
# (61657, 25)
#
# Ajustando tabela: processos-trf3_3.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_3.csv
# (23652, 25)
#
# Ajustando tabela: processos-trf3_4.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_4.csv
# (8659, 25)
#
# Ajustando tabela: processos-trf3_5.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_5.csv
# (701026, 32)
#
# Ajustando tabela: processos-trf3_6.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_6.csv
# (401420, 31)
#
# Ajustando tabela: processos-trf3_7.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_7.csv
# (315174, 31)
#
# Ajustando tabela: processos-trf3_8.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_8.csv
# (18986, 30)
#
# Ajustando tabela: processos-trf3_9.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf3/processos-trf3_9.csv
# (194690, 32)
#
# Ajustando tabela: processos-trf4_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_1.csv
# (722972, 27)
#
# Ajustando tabela: processos-trf4_10.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_10.csv
# (178907, 35)
#
# Ajustando tabela: processos-trf4_11.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_11.csv
# (134354, 39)
#
# Ajustando tabela: processos-trf4_12.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_12.csv
# (14405, 35)
#
# Ajustando tabela: processos-trf4_3.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_3.csv
# (540458, 27)
#
# Ajustando tabela: processos-trf4_4.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_4.csv
# (60714, 26)
#
# Ajustando tabela: processos-trf4_5_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_5_1.csv
# (200000, 36)
#
# Ajustando tabela: processos-trf4_5_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_5_2.csv
# (213348, 36)
#
# Ajustando tabela: processos-trf4_6_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_6_1.csv
# (300000, 36)
#
# Ajustando tabela: processos-trf4_6_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_6_2.csv
# (334950, 36)
#
# Ajustando tabela: processos-trf4_7_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_7_1.csv
# (300000, 36)
#
# Ajustando tabela: processos-trf4_7_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_7_2.csv
# (334141, 36)
#
# Ajustando tabela: processos-trf4_8.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_8.csv
# (59096, 35)
#
# Ajustando tabela: processos-trf4_9.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf4/processos-trf4_9.csv
# (354779, 35)
#
# Ajustando tabela: processos-trf5_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_1.csv
# (238022, 27)
#
# Ajustando tabela: processos-trf5_10.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_10.csv
# (377347, 36)
#
# Ajustando tabela: processos-trf5_11.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_11.csv
# (45731, 35)
#
# Ajustando tabela: processos-trf5_12.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_12.csv
# (106, 34)
#
# Ajustando tabela: processos-trf5_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_2.csv
# (435093, 27)
#
# Ajustando tabela: processos-trf5_3.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_3.csv
# (538323, 27)
#
# Ajustando tabela: processos-trf5_4.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_4.csv
# (70626, 27)
#
# Ajustando tabela: processos-trf5_5_1.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_5_1.csv
# (400000, 39)
#
# Ajustando tabela: processos-trf5_5_2.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_5_2.csv
# (315364, 39)
#
# Ajustando tabela: processos-trf5_6.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_6.csv
# (664800, 38)
#
# Ajustando tabela: processos-trf5_7.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_7.csv
# (363298, 38)
#
# Ajustando tabela: processos-trf5_8.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_8.csv
# (35365, 37)
#
# Ajustando tabela: processos-trf5_9.csv
# dados/01_tabelas_extraidas/00_justica_federal/processos-trf5/processos-trf5_9.csv
# (354174, 36)
#
# Finalizada transformação das tabelas!!
